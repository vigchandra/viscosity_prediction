# %%
import pandas as pd
import numpy as np
import os
import altair as alt
import glob
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ## Read Files

# %%
# assign directory
directory = 'new_polymer_rheology/'

df_in = pd.DataFrame()


# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
        pd.read_xlsx(f)
        df_in.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a387e0d984c5> in <module>
#      10     # checking if it is a file
#      11     if os.path.isfile(f):
# ---> 12         pd.read_xlsx(f)
#      13         df_in.append()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
for filename in os.scandir(directory):
    if filename.is_file():
        df = pd.read_excel(filename.path)

# %%
df_sheets = pd.ExcelFile('new_polymer_rheology/Polymer DPTLB 2070 C_1200ppm.xlsx')
df_sheets.sheet_names
# Out:
# ['25 c', '40 C', '60 C', '70 C', '80 C']

# %%
one_file = pd.DataFrame()
for i in df_sheets.sheet_names:
    df = pd.DataFrame(df_sheets.parse(i, skiprows=2, usecols=range(2,10)))
    df = df[1:]
    print(df.columns, df.shape)
df
# Out:
# Index(['Stress', 'Shear rate', 'Viscosity', 'Step time', 'Temperature',
#        'Normal stress'],
#       dtype='object') (31, 6)
# Index(['Stress', 'Shear rate', 'Viscosity', 'Step time', 'Temperature',
#        'Normal stress'],
#       dtype='object') (31, 6)
# Index(['Stress', 'Shear rate', 'Viscosity', 'Step time', 'Temperature',
#        'Normal stress'],
#       dtype='object') (31, 6)
# Index(['Stress', 'Shear rate', 'Viscosity', 'Step time', 'Temperature',
#        'Normal stress'],
#       dtype='object') (31, 6)
# Index(['Stress', 'Shear rate', 'Viscosity', 'Step time', 'Temperature',
#        'Normal stress'],
#       dtype='object') (31, 6)
#        Stress Shear rate   Viscosity Step time Temperature Normal stress
# 1   0.0123171   0.999999   0.0123171   39.9688      80.202      0.397763
# 2   0.0174577    1.25891   0.0138673   80.1094      80.199      0.388426
# 3   0.0170774    1.58488   0.0107752   120.219      80.118      0.390667
# ...

# %%
df = pd.read_excel('new_polymer_rheology/Polymer DPTLB 2070 C_1200ppm.xlsx', skiprows=2, )
df
# Out:
#     Unnamed: 0  Unnamed: 1      Stress Shear rate   Viscosity Step time  \
# 0          NaN         NaN          Pa        1/s        Pa.s         s
# 1          NaN         NaN  0.00878494          1  0.00878493   39.9844
# 2          NaN         NaN   0.0024808    1.25893  0.00197057   80.0781
# 3          NaN         NaN  0.00876551    1.58491  0.00553059   120.203
# 4          NaN         NaN   0.0106932    1.99524  0.00535936   160.281
# 5          NaN         NaN   0.0122106    2.51189  0.00486113   200.453
# 6          NaN         NaN   0.0143646    3.16228  0.00454249   240.531
# 7          NaN         NaN   0.0176709    3.98111  0.00443868   280.734
# 8          NaN         NaN   0.0221262    5.01189  0.00441474   320.844
# 9          NaN         NaN   0.0279811    6.30962  0.00443468   360.906
# 10         NaN         NaN   0.0346022    7.94316  0.00435623   401.063
# 11         NaN         NaN   0.0439539         10  0.00439539   441.141
# ...

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1        25 C  Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN         NaN        NaN
# 1          NaN         NaN      Stress  Shear rate   Viscosity  Step time
# 2          NaN         NaN          Pa         1/s        Pa.s          s
# 3          NaN         NaN  0.00878494           1  0.00878493    39.9844
# 4          NaN         NaN   0.0024808     1.25893  0.00197057    80.0781
# 5          NaN         NaN  0.00876551     1.58491  0.00553059    120.203
# 6          NaN         NaN   0.0106932     1.99524  0.00535936    160.281
# 7          NaN         NaN   0.0122106     2.51189  0.00486113    200.453
# 8          NaN         NaN   0.0143646     3.16228  0.00454249    240.531
# 9          NaN         NaN   0.0176709     3.98111  0.00443868    280.734
# 10         NaN         NaN   0.0221262     5.01189  0.00441474    320.844
# 11         NaN         NaN   0.0279811     6.30962  0.00443468    360.906
# ...
